# %% [markdown]
# ##Metastore Level storage
# -Metastore is attached to the Data Lake
# -Catalog is managed
# -Schema is managed
# -Object is managed

# %% [markdown]
# ###Create Catalog

# %%
# %sql
create catalog if not exists e_commerce_catalog;

# %% [markdown]
# ###Create Schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS e_commerce_catalog.bronze_schema;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS e_commerce_catalog.silver_schema;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS e_commerce_catalog.gold_schema;
